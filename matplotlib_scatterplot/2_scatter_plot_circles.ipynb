# %%
"""
    @Author: Mayank Anand
    @Date: 2022-03-29
    @Last Modified by: Mayank Anand
    @Last Modified time: 2022-03-29
    @Title: MatPlotLib Programs - Drawing a Scatter plot with empty circles of Random Distributions
"""
# Out:
# '\n    @Author: Mayank Anand\n    @Date: 2022-03-29\n    @Last Modified by: Mayank Anand\n    @Last Modified time: 2022-03-29\n    @Title: MatPlotLib Programs - Drawing a Scatter plot with empty circles of Random Distributions\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_scatter_plot(x_input, y_input):
    """
    Description:
        Plots Scatter plot with empty circles using given x and y inputs.
    Parameter:
        x_input: List with values to be plotted as X-Axis.
        y_input: List with values to be plotted on Y-Axis.
    Return:
        None.
    """
    plt.scatter(x_input, y_input, facecolor='none', edgecolor='blue')

# %%
def main():
    sample_x = np.random.rand(100)
    sample_y = np.random.rand(100)
    plot_scatter_plot(sample_x, sample_y)
    plt.show()

# %%
if __name__ == "__main__":
    main()

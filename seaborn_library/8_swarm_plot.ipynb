# %% [markdown]
# """
#
#
#     @Author: Mayank Anand
#     @Date: 2022-03-31
#     @Last Modified by: Mayank Anand
#     @Last Modified time: 2022-03-31
#     @Title: Seaborn Programs - Create a Swarm plot
#
# """

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def main():
    data = sns.load_dataset("tips")
    sns.swarmplot(x = "size", y = "total_bill", data = data)

# %%
if __name__ == "__main__":
    main()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

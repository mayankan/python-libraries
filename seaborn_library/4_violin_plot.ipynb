# %% [markdown]
# """
#
#
#     @Author: Mayank Anand
#     @Date: 2022-03-31
#     @Last Modified by: Mayank Anand
#     @Last Modified time: 2022-03-31
#     @Title: Seaborn Programs - Create a Violin plot
#
# """

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def main():
    data = sns.load_dataset("tips")
    sns.violinplot(x = "sex", y = "total_bill", data = data)

# %%
if __name__ == "__main__":
    main()
